], [-38.82819747924805, -415.2558898925781, -49.39480209350583], [-32.448974609375, -414.5097351074219, -49.802940368652315], [-26.427337646484375, -413.105224609375, -49.006649017333956], [-10.370162963867188, -401.14990234375, -42.15315246582029], [-25.56352996826172, -409.57623291015625, -51.37562179565427], [-32.032630920410156, -411.5163269042969, -52.31269073486325], [-39.0578498840332, -412.0579833984375, -51.87834930419919]]
#['nose', 'neck', 'right_shoulder', 'right_elbow', 'right_wrist', 'left_shoulder', 'left_elbow', 'left_wrist', 'pelvis', 'right_hip', 'right_knee', 'right_ankle', 'left_hip', 'left_knee', 'left_ankle', 'right_eye', 'left_eye', 'right_ear', 'left_ear', 'left_big_toe', 'left_small_toe', 'left_heel', 'right_big_toe', 'right_small_toe', 'right_heel', 'left_wrist', 'left_thumb1', 'left_thumb2', 'left_thumb3', 'left_thumb', 'left_index1', 'left_index2', 'left_index3', 'left_index', 'left_middle1', 'left_middle2', 'left_middle3', 'left_middle', 'left_ring1', 'left_ring2', 'left_ring3', 'left_ring', 'left_pinky1', 'left_pinky2', 'left_pinky3', 'left_pinky', 'right_wrist', 'right_thumb1', 'right_thumb2', 'right_thumb3', 'right_thumb', 'right_index1', 'right_index2', 'right_index3', 'right_index', 'right_middle1', 'right_middle2', 'right_middle3', 'right_middle', 'right_ring1', 'right_ring2', 'right_ring3', 'right_ring', 'right_pinky1', 'right_pinky2', 'right_pinky3', 'right_pinky', 'right_eye_brow1', 'right_eye_brow2', 'right_eye_brow3', 'right_eye_brow4', 'right_eye_brow5', 'left_eye_brow5', 'left_eye_brow4', 'left_eye_brow3', 'left_eye_brow2', 'left_eye_brow1', 'nose1', 'nose2', 'nose3', 'nose4', 'right_nose_2', 'right_nose_1', 'nose_middle', 'left_nose_1', 'left_nose_2', 'right_eye1', 'right_eye2', 'right_eye3', 'right_eye4', 'right_eye5', 'right_eye6', 'left_eye4', 'left_eye3', 'left_eye2', 'left_eye1', 'left_eye6', 'left_eye5', 'right_mouth_1', 'right_mouth_2', 'right_mouth_3', 'mouth_top', 'left_mouth_3', 'left_mouth_2', 'left_mouth_1', 'left_mouth_5', 'left_mouth_4', 'mouth_bottom', 'right_mouth_4', 'right_mouth_5', 'right_lip_1', 'right_lip_2', 'lip_top', 'left_lip_2', 'left_lip_1', 'left_lip_3', 'lip_bottom', 'right_lip_3']

# %%
import matplotlib.pyplot as plt

# Extract x, y, and z coordinates from the joints list
x = [joint[0] for joint in joints]
y = [joint[1] for joint in joints]
z = [joint[2] for joint in joints]

# Plot the joints
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
#calculate the amount of total joints points
print(len(joints)) #118

# %% [markdown]
# The 118 joints follow the openpose ordering. https://github.com/CMU-Perceptual-Computing-Lab/openpose/blob/master/doc/output.md#keypoint-ordering-in-cpython. This code contains the order in which the joints are being read: https://github.com/vchoutas/smplify-x/blob/master/smplifyx/data_parser.py.
#
# joint_mapper.joint_maps
# tensor([ 55,  12,  17,  19,  21,  16,  18,  20,   0,   2,   5,   8,   1,   4,
#           7,  56,  57,  58,  59,  60,  61,  62,  63,  64,  65,  20,  37,  38,
#          39,  66,  25,  26,  27,  67,  28,  29,  30,  68,  34,  35,  36,  69,
#          31,  32,  33,  70,  21,  52,  53,  54,  71,  40,  41,  42,  72,  43,
#          44,  45,  73,  49,  50,  51,  74,  46,  47,  48,  75,  76,  77,  78,
#          79,  80,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,  92,
#          93,  94,  95,  96,  97,  98,  99, 100, 101, 102, 103, 104, 105, 106,
#         107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120,
#         121, 122, 123, 124, 125, 126])
# len(joint_mapper.joint_maps)
# 118

# %%
KEYPOINT_NAMES = [
    'pelvis',
    'left_hip',
    'right_hip',
    'spine1',
    'left_knee',
    'right_knee',
    'spine2',
    'left_ankle',
    'right_ankle',
    'spine3',
    'left_foot',
    'right_foot',
    'neck',
    'left_collar',
    'right_collar',
    'head',
    'left_shoulder',
    'right_shoulder',
    'left_elbow',
    'right_elbow',
    'left_wrist',
    'right_wrist',
    'jaw',
    'left_eye_smplx',
    'right_eye_smplx',
    'left_index1',
    'left_index2',
    'left_index3',
    'left_middle1',
    'left_middle2',
    'left_middle3',
    'left_pinky1',
    'left_pinky2',
    'left_pinky3',
    'left_ring1',
    'left_ring2',
    'left_ring3',
    'left_thumb1',
    'left_thumb2',
    'left_thumb3',
    'right_index1',
    'right_index2',
    'right_index3',
    'right_middle1',
    'right_middle2',
    'right_middle3',
    'right_pinky1',
    'right_pinky2',
    'right_pinky3',
    'right_ring1',
    'right_ring2',
    'right_ring3',
    'right_thumb1',
    'right_thumb2',
    'right_thumb3',
    'nose',
    'right_eye',
    'left_eye',
    'right_ear',
    'left_ear',
    'left_big_toe',
    'left_small_toe',
    'left_heel',
    'right_big_toe',
    'right_small_toe',
    'right_heel',
    'left_thumb',
    'left_index',
    'left_middle',
    'left_ring',
    'left_pinky',
    'right_thumb',
    'right_index',
    'right_middle',
    'right_ring',
    'right_pinky',
    'right_eye_brow1',
    'right_eye_brow2',
    'right_eye_brow3',
    'right_eye_brow4',
    'right_eye_brow5',
    'left_eye_brow5',
    'left_eye_brow4',
    'left_eye_brow3',
    'left_eye_brow2',
    'left_eye_brow1',
    'nose1',
    'nose2',
    'nose3',
    'nose4',
    'right_nose_2',
    'right_nose_1',
    'nose_middle',
    'left_nose_1',
    'left_nose_2',
    'right_eye1',
    'right_eye2',
    'right_eye3',
    'right_eye4',
    'right_eye5',
    'right_eye6',
    'left_eye4',
    'left_eye3',
    'left_eye2',
    'left_eye1',
    'left_eye6',
    'left_eye5',
    'right_mouth_1',
    'right_mouth_2',
    'right_mouth_3',
    'mouth_top',
    'left_mouth_3',
    'left_mouth_2',
    'left_mouth_1',
    'left_mouth_5',  # 59 in OpenPose output
    'left_mouth_4',  # 58 in OpenPose output
    'mouth_bottom',
    'right_mouth_4',
    'right_mouth_5',
    'right_lip_1',
    'right_lip_2',
    'lip_top',
    'left_lip_2',
    'left_lip_1',
    'left_lip_3',
    'lip_bottom',
    'right_lip_3',
    # Face contour
    'right_contour_1',
    'right_contour_2',
    'right_contour_3',
    'right_contour_4',
    'right_contour_5',
    'right_contour_6',
    'right_contour_7',
    'right_contour_8',
    'contour_middle',
    'left_contour_8',
    'left_contour_7',
    'left_contour_6',
    'left_contour_5',
    'left_contour_4',
    'left_contour_3',
    'left_contour_2',
    'left_contour_1',
]
joint_maps=[ 55,  12,  17,  19,  21,  16,  18,  20,   0,   2,   5,   8,   1,   4,
          7,  56,  57,  58,  59,  60,  61,  62,  63,  64,  65,  20,  37,  38,
         39,  66,  25,  26,  27,  67,  28,  29,  30,  68,  34,  35,  36,  69,
         31,  32,  33,  70,  21,  52,  53,  54,  71,  40,  41,  42,  72,  43,
         44,  45,  73,  49,  50,  51,  74,  46,  47,  48,  75,  76,  77,  78,
         79,  80,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,  92,
         93,  94,  95,  96,  97,  98,  99, 100, 101, 102, 103, 104, 105, 106,
        107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120,
        121, 122, 123, 124, 125, 126]
# get the names of the mapped joints
joint_names = [KEYPOINT_NAMES[i] for i in joint_maps]
print(joint_names)
# Out:
# ['nose', 'neck', 'right_shoulder', 'right_elbow', 'right_wrist', 'left_shoulder', 'left_elbow', 'left_wrist', 'pelvis', 'right_hip', 'right_knee', 'right_ankle', 'left_hip', 'left_knee', 'left_ankle', 'right_eye', 'left_eye', 'right_ear', 'left_ear', 'left_big_toe', 'left_small_toe', 'left_heel', 'right_big_toe', 'right_small_toe', 'right_heel', 'left_wrist', 'left_thumb1', 'left_thumb2', 'left_thumb3', 'left_thumb', 'left_index1', 'left_index2', 'left_index3', 'left_index', 'left_middle1', 'left_middle2', 'left_middle3', 'left_middle', 'left_ring1', 'left_ring2', 'left_ring3', 'left_ring', 'left_pinky1', 'left_pinky2', 'left_pinky3', 'left_pinky', 'right_wrist', 'right_thumb1', 'right_thumb2', 'right_thumb3', 'right_thumb', 'right_index1', 'right_index2', 'right_index3', 'right_index', 'right_middle1', 'right_middle2', 'right_middle3', 'right_middle', 'right_ring1', 'right_ring2', 'right_ring3', 'right_ring', 'right_pinky1', 'right_pinky2', 'right_pinky3', 'right_pinky', 'right_eye_
# ...

# %%
# blender results
Bone: root, Head Position in World Space: <Vector (0.0000, 0.0000, 1295.8771)>
Bone: pelvis, Head Position in World Space: <Vector (1.2787, -14.2033, 919.4230)>
Bone: left_hip, Head Position in World Space: <Vector (59.4993, 9.1911, 822.5202)>
Bone: left_knee, Head Position in World Space: <Vector (185.2868, -240.2475, 521.0230)>
Bone: left_ankle, Head Position in World Space: <Vector (-10.0731, 22.4258, 230.7416)>
Bone: left_foot, Head Position in World Space: <Vector (9.8794, 62.6452, 79.0429)>
Bone: right_hip, Head Position in World Space: <Vector (-58.7641, 2.1088, 811.6835)>
Bone: right_knee, Head Position in World Space: <Vector (-228.0848, -237.6039, 552.6004)>
Bone: right_ankle, Head Position in World Space: <Vector (-326.7425, -29.0857, 167.2115)>
Bone: right_foot, Head Position in World Space: <Vector (-428.9987, -128.7983, 92.1694)>
Bone: spine1, Head Position in World Space: <Vector (-0.2770, 25.3229, 1033.3398)>
Bone: spine2, Head Position in World Space: <Vector (-17.9848, -84.0019, 1142.5654)>
Bone: spine3, Head Position in World Space: <Vector (-39.8005, -141.2528, 1163.7662)>
Bone: neck, Head Position in World Space: <Vector (-70.4473, -223.7694, 1313.4917)>
Bone: head, Head Position in World Space: <Vector (-29.6905, -381.3451, 1345.6923)>
Bone: jaw, Head Position in World Space: <Vector (-51.3658, -380.7677, 1349.5071)>
Bone: left_eye, Head Position in World Space: <Vector (1.8703, -452.6724, 1316.9371)>
Bone: right_eye, Head Position in World Space: <Vector (-62.8705, -463.5810, 1314.4095)>
Bone: left_collar, Head Position in World Space: <Vector (-7.1395, -190.8796, 1230.7297)>
Bone: left_shoulder, Head Position in World Space: <Vector (98.0311, -298.9780, 1275.0767)>
Bone: left_elbow, Head Position in World Space: <Vector (293.9207, -375.8977, 1098.1517)>
Bone: left_wrist, Head Position in World Space: <Vector (291.7658, -652.4154, 1134.0540)>
Bone: left_index1, Head Position in World Space: <Vector (259.0695, -744.3486, 1187.9264)>
Bone: left_index2, Head Position in World Space: <Vector (252.4768, -770.9659, 1208.0688)>
Bone: left_index3, Head Position in World Space: <Vector (250.0686, -792.2529, 1218.7638)>
Bone: left_middle1, Head Position in World Space: <Vector (283.7959, -753.7024, 1193.1035)>
Bone: left_middle2, Head Position in World Space: <Vector (285.2490, -780.9957, 1210.8453)>
Bone: left_middle3, Head Position in World Space: <Vector (286.9702, -803.5992, 1221.8892)>
Bone: left_pinky1, Head Position in World Space: <Vector (327.7043, -743.2308, 1167.9907)>
Bone: left_pinky2, Head Position in World Space: <Vector (337.8119, -760.4137, 1175.1154)>
Bone: left_pinky3, Head Position in World Space: <Vector (347.0511, -777.3185, 1181.8444)>
Bone: left_ring1, Head Position in World Space: <Vector (309.6324, -748.9645, 1181.8790)>
Bone: left_ring2, Head Position in World Space: <Vector (311.9407, -774.3746, 1198.5342)>
Bone: left_ring3, Head Position in World Space: <Vector (316.1324, -796.9009, 1209.3416)>
Bone: left_thumb1, Head Position in World Space: <Vector (256.8904, -694.7719, 1142.5128)>
Bone: left_thumb2, Head Position in World Space: <Vector (228.2174, -703.9954, 1155.5585)>
Bone: left_thumb3, Head Position in World Space: <Vector (208.5287, -721.6130, 1164.3895)>
Bone: right_collar, Head Position in World Space: <Vector (-96.4576, -177.4023, 1227.3003)>
Bone: right_shoulder, Head Position in World Space: <Vector (-197.5819, -281.8509, 1244.0220)>
Bone: right_elbow, Head Position in World Space: <Vector (-215.9258, -463.0268, 1026.7765)>
Bone: right_wrist, Head Position in World Space: <Vector (-243.5936, -730.8015, 1036.7648)>
Bone: right_index1, Head Position in World Space: <Vector (-286.2718, -806.2141, 1106.2885)>
Bone: right_index2, Head Position in World Space: <Vector (-301.9586, -824.5200, 1130.2988)>
Bone: right_index3, Head Position in World Space: <Vector (-315.2632, -839.4818, 1143.4316)>
Bone: right_middle1, Head Position in World Space: <Vector (-312.1304, -799.8993, 1102.1327)>
Bone: right_middle2, Head Position in World Space: <Vector (-333.7697, -815.5483, 1120.8053)>
Bone: right_middle3, Head Position in World Space: <Vector (-351.1122, -829.4219, 1132.7469)>
Bone: right_pinky1, Head Position in World Space: <Vector (-333.2140, -777.8069, 1060.4718)>
Bone: right_pinky2, Head Position in World Space: <Vector (-352.8404, -784.4156, 1064.8607)>
Bone: right_pinky3, Head Position in World Space: <Vector (-371.5318, -791.3549, 1069.2062)>
Bone: right_ring1, Head Position in World Space: <Vector (-326.3109, -786.9099, 1081.0098)>
Bone: right_ring2, Head Position in World Space: <Vector (-347.2285, -800.9622, 1098.1366)>
Bone: right_ring3, Head Position in World Space: <Vector (-366.3684, -813.6293, 1108.8613)>
Bone: right_thumb1, Head Position in World Space: <Vector (-243.7898, -781.7958, 1060.2001)>
Bone: right_thumb2, Head Position in World Space: <Vector (-230.5025, -799.2265, 1084.6328)>
Bone: right_thumb3, Head Position in World Space: <Vector (-227.8636, -820.3555, 1102.5945)>

# %%
import re

# Sample text containing the bone information
text = """
Bone: root, Head Position in World Space: <Vector (0.0000, 0.0000, 1295.8771)>
Bone: pelvis, Head Position in World Space: <Vector (1.2787, -14.2033, 919.4230)>
Bone: left_hip, Head Position in World Space: <Vector (59.4993, 9.1911, 822.5202)>
Bone: left_knee, Head Position in World Space: <Vector (185.2868, -240.2475, 521.0230)>
Bone: left_ankle, Head Position in World Space: <Vector (-10.0731, 22.4258, 230.7416)>
Bone: left_foot, Head Position in World Space: <Vector (9.8794, 62.6452, 79.0429)>
Bone: right_hip, Head Position in World Space: <Vector (-58.7641, 2.1088, 811.6835)>
Bone: right_knee, Head Position in World Space: <Vector (-228.0848, -237.6039, 552.6004)>
Bone: right_ankle, Head Position in World Space: <Vector (-326.7425, -29.0857, 167.2115)>
Bone: right_foot, Head Position in World Space: <Vector (-428.9987, -128.7983, 92.1694)>
Bone: spine1, Head Position in World Space: <Vector (-0.2770, 25.3229, 1033.3398)>
Bone: spine2, Head Position in World Space: <Vector (-17.9848, -84.0019, 1142.5654)>
Bone: spine3, Head Position in World Space: <Vector (-39.8005, -141.2528, 1163.7662)>
Bone: neck, Head Position in World Space: <Vector (-70.4473, -223.7694, 1313.4917)>
Bone: head, Head Position in World Space: <Vector (-29.6905, -381.3451, 1345.6923)>
Bone: jaw, Head Position in World Space: <Vector (-51.3658, -380.7677, 1349.5071)>
Bone: left_eye, Head Position in World Space: <Vector (1.8703, -452.6724, 1316.9371)>
Bone: right_eye, Head Position in World Space: <Vector (-62.8705, -463.5810, 1314.4095)>
Bone: left_collar, Head Position in World Space: <Vector (-7.1395, -190.8796, 1230.7297)>
Bone: left_shoulder, Head Position in World Space: <Vector (98.0311, -298.9780, 1275.0767)>
Bone: left_elbow, Head Position in World Space: <Vector (293.9207, -375.8977, 1098.1517)>
Bone: left_wrist, Head Position in World Space: <Vector (291.7658, -652.4154, 1134.0540)>
Bone: left_index1, Head Position in World Space: <Vector (259.0695, -744.3486, 1187.9264)>
Bone: left_index2, Head Position in World Space: <Vector (252.4768, -770.9659, 1208.0688)>
Bone: left_index3, Head Position in World Space: <Vector (250.0686, -792.2529, 1218.7638)>
Bone: left_middle1, Head Position in World Space: <Vector (283.7959, -753.7024, 1193.1035)>
Bone: left_middle2, Head Position in World Space: <Vector (285.2490, -780.9957, 1210.8453)>
Bone: left_middle3, Head Position in World Space: <Vector (286.9702, -803.5992, 1221.8892)>
Bone: left_pinky1, Head Position in World Space: <Vector (327.7043, -743.2308, 1167.9907)>
Bone: left_pinky2, Head Position in World Space: <Vector (337.8119, -760.4137, 1175.1154)>
Bone: left_pinky3, Head Position in World Space: <Vector (347.0511, -777.3185, 1181.8444)>
Bone: left_ring1, Head Position in World Space: <Vector (309.6324, -748.9645, 1181.8790)>
Bone: left_ring2, Head Position in World Space: <Vector (311.9407, -774.3746, 1198.5342)>
Bone: left_ring3, Head Position in World Space: <Vector (316.1324, -796.9009, 1209.3416)>
Bone: left_thumb1, Head Position in World Space: <Vector (256.8904, -694.7719, 1142.5128)>
Bone: left_thumb2, Head Position in World Space: <Vector (228.2174, -703.9954, 1155.5585)>
Bone: left_thumb3, Head Position in World Space: <Vector (208.5287, -721.6130, 1164.3895)>
Bone: right_collar, Head Position in World Space: <Vector (-96.4576, -177.4023, 1227.3003)>
Bone: right_shoulder, Head Position in World Space: <Vector (-197.5819, -281.8509, 1244.0220)>
Bone: right_elbow, Head Position in World Space: <Vector (-215.9258, -463.0268, 1026.7765)>
Bone: right_wrist, Head Position in World Space: <Vector (-243.5936, -730.8015, 1036.7648)>
Bone: right_index1, Head Position in World Space: <Vector (-286.2718, -806.2141, 1106.2885)>
Bone: right_index2, Head Position in World Space: <Vector (-301.9586, -824.5200, 1130.2988)>
Bone: right_index3, Head Position in World Space: <Vector (-315.2632, -839.4818, 1143.4316)>
Bone: right_middle1, Head Position in World Space: <Vector (-312.1304, -799.8993, 1102.1327)>
Bone: right_middle2, Head Position in World Space: <Vector (-333.7697, -815.5483, 1120.8053)>
Bone: right_middle3, Head Position in World Space: <Vector (-351.1122, -829.4219, 1132.7469)>
Bone: right_pinky1, Head Position in World Space: <Vector (-333.2140, -777.8069, 1060.4718)>
Bone: right_pinky2, Head Position in World Space: <Vector (-352.8404, -784.4156, 1064.8607)>
Bone: right_pinky3, Head Position in World Space: <Vector (-371.5318, -791.3549, 1069.2062)>
Bone: right_ring1, Head Position in World Space: <Vector (-326.3109, -786.9099, 1081.0098)>
Bone: right_ring2, Head Position in World Space: <Vector (-347.2285, -800.9622, 1098.1366)>
Bone: right_ring3, Head Position in World Space: <Vector (-366.3684, -813.6293, 1108.8613)>
Bone: right_thumb1, Head Position in World Space: <Vector (-243.7898, -781.7958, 1060.2001)>
Bone: right_thumb2, Head Position in World Space: <Vector (-230.5025, -799.2265, 1084.6328)>
Bone: right_thumb3, Head Position in World Space: <Vector (-227.8636, -820.3555, 1102.5945)>
"""

# Regular expression to match the bone name and its position
pattern = r"Bone: (\w+), Head Position in World Space: <Vector \(([^)]+)\)>"

# Find all matches in the text
matches = re.findall(pattern, text)

# Construct the list of lists
#blender_joints = [[match[0]] + list(map(float, match[1].split(', '))) for match in matches]
blender_joints = [list(map(float, match[1].split(', '))) for match in matches]

# Example: print the constructed list of lists
for blender_joint in blender_joints:
    print(blender_joint)
# Out:
# [0.0, 0.0, 1295.8771]
# [1.2787, -14.2033, 919.423]
# [59.4993, 9.1911, 822.5202]
# [185.2868, -240.2475, 521.023]
# [-10.0731, 22.4258, 230.7416]
# [9.8794, 62.6452, 79.0429]
# [-58.7641, 2.1088, 811.6835]
# [-228.0848, -237.6039, 552.6004]
# [-326.7425, -29.0857, 167.2115]
# [-428.9987, -128.7983, 92.1694]
# [-0.277, 25.3229, 1033.3398]
# [-17.9848, -84.0019, 1142.5654]
# [-39.8005, -141.2528, 1163.7662]
# [-70.4473, -223.7694, 1313.4917]
# [-29.6905, -381.3451, 1345.6923]
# [-51.3658, -380.7677, 1349.5071]
# [1.8703, -452.6724, 1316.9371]
# [-62.8705, -463.581, 1314.4095]
# [-7.1395, -190.8796, 1230.7297]
# [98.0311, -298.978, 1275.0767]
# [293.9207, -375.8977, 1098.1517]
# [291.7658, -652.4154, 1134.054]
# [259.0695, -744.3486, 1187.9264]
# [252.4768, -770.9659, 1208.0688]
# [250.0686, -792.2529, 1218.7638]
# [283.7959, -753.7024, 1193.1035]
# [285.249, -780.9957, 1210.8453]
# [286.9702, -803.5992, 1221.8892]
# [327.7043, -743.2308, 1167.9907]
# [337.8119, -760.4137, 1175.1154]
# ...

# %%
import matplotlib.pyplot as plt

# Extract x, y, and z coordinates from the joints list
x = [blender_joint[0] for blender_joint in blender_joints]
y = [blender_joint[1] for blender_joint in blender_joints]
z = [blender_joint[2] for blender_joint in blender_joints]

# Plot the joints
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract x, y, and z coordinates from the blender_joints list
blender_x = [blender_joint[0] for blender_joint in blender_joints]
blender_y = [blender_joint[1] for blender_joint in blender_joints]
blender_z = [blender_joint[2] for blender_joint in blender_joints]

# Extract x, y, and z coordinates from the joints list
x = [joint[0] for joint in joints]
y = [joint[1] for joint in joints]
z = [joint[2] for joint in joints]

# Plot the joints
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(blender_x, blender_y, blender_z, label='Blender Joints')
ax.scatter(x, y, z, label='Joints')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.legend()
plt.show()

# %%
Bone: pelvis, Head Position in Pose Mode: <Vector (0.1279, -37.6454, 1.4203)>
Bone: left_hip, Head Position in Pose Mode: <Vector (5.9499, -47.3357, -0.9191)>

# %%
import os
import platform
import numpy as np
from enum import Enum

VERSION = (2023, 9, 1)

SMPLX_MODELFILE = "smplx.blend"
SUPR_MODELFILE = "supr.blend"
SMPLH_MODELFILE = "smplh.blend"

SMPLX_JOINT_NAMES = [
    'pelvis',
    'left_hip',
    'right_hip',
    'spine1',
    'left_knee',
    'right_knee',
    'spine2',
    'left_ankle',
    'right_ankle',
    'spine3',
    'left_foot',
    'right_foot',
    'neck',
    'left_collar',
    'right_collar',
    'head',
    'left_shoulder',
    'right_shoulder',
    'left_elbow',
    'right_elbow',
    'left_wrist',
    'right_wrist',
    'jaw',
    'left_eye',
    'right_eye',
    'left_index1',
    'left_index2',
    'left_index3',
    'left_middle1',
    'left_middle2',
    'left_middle3',
    'left_pinky1',
    'left_pinky2',
    'left_pinky3',
    'left_ring1',
    'left_ring2',
    'left_ring3',
    'left_thumb1',
    'left_thumb2',
    'left_thumb3',
    'right_index1',
    'right_index2',
    'right_index3',
    'right_middle1',
    'right_middle2',
    'right_middle3',
    'right_pinky1',
    'right_pinky2',
    'right_pinky3',
    'right_ring1',
    'right_ring2',
    'right_ring3',
    'right_thumb1',
    'right_thumb2',
    'right_thumb3'
    ]

SMPLH_JOINT_NAMES = [
    'pelvis',
    'left_hip',
    'right_hip',
    'spine1',
    'left_knee',
    'right_knee',
    'spine2',
    'left_ankle',
    'right_ankle',
    'spine3',
    'left_foot',
    'right_foot',
    'neck',
    'left_collar',
    'right_collar',
    'head',
    'left_shoulder',
    'right_shoulder',
    'left_elbow',
    'right_elbow',
    'left_wrist',
    'right_wrist',
    'left_index1',
    'left_index2',
    'left_index3',
    'left_middle1',
    'left_middle2',
    'left_middle3',
    'left_pinky1',
    'left_pinky2',
    'left_pinky3',
    'left_ring1',
    'left_ring2',
    'left_ring3',
    'left_thumb1',
    'left_thumb2',
    'left_thumb3',
    'right_index1',
    'right_index2',
    'right_index3',
    'right_middle1',
    'right_middle2',
    'right_middle3',
    'right_pinky1',
    'right_pinky2',
    'right_pinky3',
    'right_ring1',
    'right_ring2',
    'right_ring3',
    'right_thumb1',
    'right_thumb2',
    'right_thumb3'
    ]

SUPR_JOINT_NAMES = [
    "pelvis",
    "left_hip",
    "right_hip",
    "spine1",
    "left_knee",
    "right_knee",
    "spine2",
    "left_ankle",
    "right_ankle",
    "spine3",
    "left_foot",
    "right_foot",
    "neck",
    "left_collar",
    "right_collar",
    "head",
    "left_shoulder",
    "right_shoulder",
    "left_elbow",
    "right_elbow",
    "left_wrist",
    "right_wrist",
    "jaw",
    "left_eye",
    "right_eye",
    "left_index1",
    "left_index2",
    "left_index3",
    "left_middle1",
    "left_middle2",
    "left_middle3",
    "left_pinky1",
    "left_pinky2",
    "left_pinky3",
    "left_ring1",
    "left_ring2",
    "left_ring3",
    "left_thumb1",
    "left_thumb2",
    "left_thumb3",
    "right_index1",
    "right_index2",
    "right_index3",
    "right_middle1",
    "right_middle2",
    "right_middle3",
    "right_pinky1",
    "right_pinky2",
    "right_pinky3",
    "right_ring1",
    "right_ring2",
    "right_ring3",
    "right_thumb1",
    "right_thumb2",
    "right_thumb3",
    "left_bigtoe1",
    "left_bigtoe2",
    "left_indextoe1",
    "left_indextoe2",
    "left_middletoe1",
    "left_middletoe2",
    "left_ringtoe1",
    "left_ringtoe2",
    "left_pinkytoe1",
    "left_pinkytoe2",
    "right_bigtoe1",
    "right_bigtoe2",
    "right_indextoe1",
    "right_indextoe2",
    "right_middletoe1",
    "right_middletoe2",
    "right_ringtoe1",
    "right_ringtoe2",
    "right_pinkytoe1",
    "right_pinkytoe2"
    ]

NUM_SMPLX_JOINTS = len(SMPLX_JOINT_NAMES)
NUM_SMPLX_BODYJOINTS = 21
NUM_SMPLX_HANDJOINTS = 15

NUM_SUPR_JOINTS = len(SUPR_JOINT_NAMES)
NUM_SUPR_BODY_JOINTS = 21    # leaving as is for now.  Not sure what to do about the toes
NUM_SUPR_HAND_JOINTS = 15 

NUM_SMPLH_JOINTS = len(SMPLX_JOINT_NAMES)
NUM_SMPLH_BODY_JOINTS = 21   
NUM_SMPLH_HAND_JOINTS = 15   # must be per hand



class MODEL_JOINT_NAMES(Enum):
    SUPR = SUPR_JOINT_NAMES
    SMPLX = SMPLX_JOINT_NAMES
    SMPLH = SMPLH_JOINT_NAMES

class MODEL_BODY_JOINTS(Enum):
    SMPLH = 21
    SMPLX = 21
    SUPR = 21

class MODEL_HAND_JOINTS(Enum):
    SMPLH = 15
    SMPLX = 15
    SUPR = 15

# %%
NUM_SMPLX_JOINTS
# Out:
# 55

# %%
import re

# Sample text containing the bone information
text = """

Bone: root, Head Position in World Space: <Vector (0.0000, 0.0000, 1295.8771)>
Bone: pelvis, Head Position in World Space: <Vector (1.2787, -14.2033, 919.4230)>
Bone: left_hip, Head Position in World Space: <Vector (59.4993, 9.1911, 822.5202)>
Bone: left_knee, Head Position in World Space: <Vector (185.2868, -240.2475, 521.0230)>
Bone: left_ankle, Head Position in World Space: <Vector (-10.0731, 22.4258, 230.7416)>
Bone: left_foot, Head Position in World Space: <Vector (9.8794, 62.6452, 79.0429)>
Bone: right_hip, Head Position in World Space: <Vector (-58.7641, 2.1088, 811.6835)>
Bone: right_knee, Head Position in World Space: <Vector (-228.0848, -237.6039, 552.6004)>
Bone: right_ankle, Head Position in World Space: <Vector (-326.7425, -29.0857, 167.2115)>
Bone: right_foot, Head Position in World Space: <Vector (-428.9987, -128.7983, 92.1694)>
Bone: spine1, Head Position in World Space: <Vector (-0.2770, 25.3229, 1033.3398)>
Bone: spine2, Head Position in World Space: <Vector (-17.9848, -84.0019, 1142.5654)>
Bone: spine3, Head Position in World Space: <Vector (-39.8005, -141.2528, 1163.7662)>
Bone: neck, Head Position in World Space: <Vector (-70.4473, -223.7694, 1313.4917)>
Bone: head, Head Position in World Space: <Vector (-29.6905, -381.3451, 1345.6923)>
Bone: jaw, Head Position in World Space: <Vector (-51.3658, -380.7677, 1349.5071)>
Bone: left_eye, Head Position in World Space: <Vector (1.8703, -452.6724, 1316.9371)>
Bone: right_eye, Head Position in World Space: <Vector (-62.8705, -463.5810, 1314.4095)>
Bone: left_collar, Head Position in World Space: <Vector (-7.1395, -190.8796, 1230.7297)>
Bone: left_shoulder, Head Position in World Space: <Vector (98.0311, -298.9780, 1275.0767)>
Bone: left_elbow, Head Position in World Space: <Vector (293.9207, -375.8977, 1098.1517)>
Bone: left_wrist, Head Position in World Space: <Vector (291.7658, -652.4154, 1134.0540)>
Bone: left_index1, Head Position in World Space: <Vector (259.0695, -744.3486, 1187.9264)>
Bone: left_index2, Head Position in World Space: <Vector (252.4768, -770.9659, 1208.0688)>
Bone: left_index3, Head Position in World Space: <Vector (250.0686, -792.2529, 1218.7638)>
Bone: left_middle1, Head Position in World Space: <Vector (283.7959, -753.7024, 1193.1035)>
Bone: left_middle2, Head Position in World Space: <Vector (285.2490, -780.9957, 1210.8453)>
Bone: left_middle3, Head Position in World Space: <Vector (286.9702, -803.5992, 1221.8892)>
Bone: left_pinky1, Head Position in World Space: <Vector (327.7043, -743.2308, 1167.9907)>
Bone: left_pinky2, Head Position in World Space: <Vector (337.8119, -760.4137, 1175.1154)>
Bone: left_pinky3, Head Position in World Space: <Vector (347.0511, -777.3185, 1181.8444)>
Bone: left_ring1, Head Position in World Space: <Vector (309.6324, -748.9645, 1181.8790)>
Bone: left_ring2, Head Position in World Space: <Vector (311.9407, -774.3746, 1198.5342)>
Bone: left_ring3, Head Position in World Space: <Vector (316.1324, -796.9009, 1209.3416)>
Bone: left_thumb1, Head Position in World Space: <Vector (256.8904, -694.7719, 1142.5128)>
Bone: left_thumb2, Head Position in World Space: <Vector (228.2174, -703.9954, 1155.5585)>
Bone: left_thumb3, Head Position in World Space: <Vector (208.5287, -721.6130, 1164.3895)>
Bone: right_collar, Head Position in World Space: <Vector (-96.4576, -177.4023, 1227.3003)>
Bone: right_shoulder, Head Position in World Space: <Vector (-197.5819, -281.8509, 1244.0220)>
Bone: right_elbow, Head Position in World Space: <Vector (-215.9258, -463.0268, 1026.7765)>
Bone: right_wrist, Head Position in World Space: <Vector (-243.5936, -730.8015, 1036.7648)>
Bone: right_index1, Head Position in World Space: <Vector (-286.2718, -806.2141, 1106.2885)>
Bone: right_index2, Head Position in World Space: <Vector (-301.9586, -824.5200, 1130.2988)>
Bone: right_index3, Head Position in World Space: <Vector (-315.2632, -839.4818, 1143.4316)>
Bone: right_middle1, Head Position in World Space: <Vector (-312.1304, -799.8993, 1102.1327)>
Bone: right_middle2, Head Position in World Space: <Vector (-333.7697, -815.5483, 1120.8053)>
Bone: right_middle3, Head Position in World Space: <Vector (-351.1122, -829.4219, 1132.7469)>
Bone: right_pinky1, Head Position in World Space: <Vector (-333.2140, -777.8069, 1060.4718)>
Bone: right_pinky2, Head Position in World Space: <Vector (-352.8404, -784.4156, 1064.8607)>
Bone: right_pinky3, Head Position in World Space: <Vector (-371.5318, -791.3549, 1069.2062)>
Bone: right_ring1, Head Position in World Space: <Vector (-326.3109, -786.9099, 1081.0098)>
Bone: right_ring2, Head Position in World Space: <Vector (-347.2285, -800.9622, 1098.1366)>
Bone: right_ring3, Head Position in World Space: <Vector (-366.3684, -813.6293, 1108.8613)>
Bone: right_thumb1, Head Position in World Space: <Vector (-243.7898, -781.7958, 1060.2001)>
Bone: right_thumb2, Head Position in World Space: <Vector (-230.5025, -799.2265, 1084.6328)>
Bone: right_thumb3, Head Position in World Space: <Vector (-227.8636, -820.3555, 1102.5945)>
"""
# Regular expression to match the bone name and its position
pattern = r"Bone: (\w+), Head Position in World Space: <Vector \(([^)]+)\)>"

# Find all matches in the text
matches = re.findall(pattern, text)

# Construct the list of lists
blender_joints = [[match[0]] + list(map(float, match[1].split(', '))) for match in matches]
# divide by 1000
blender_joints = [[joint[0]] + [joint[1]/1000, joint[2]/1000, joint[3]/1000] for joint in blender_joints]
#blender_joints = [list(map(float, match[1].split(', '))) for match in matches]

# Example: print the constructed list of lists
for blender_joint in blender_joints:
    print(blender_joint)
# save the list of lists to a file
import numpy as np
np.savetxt('blender_joints.txt', blender_joints, fmt='%s')
# Out:
# ['root', 0.0, 0.0, 1.2958771]
# ['pelvis', 0.0012787, -0.0142033, 0.919423]
# ['left_hip', 0.0594993, 0.0091911, 0.8225202]
# ['left_knee', 0.1852868, -0.2402475, 0.521023]
# ['left_ankle', -0.0100731, 0.0224258, 0.23074160000000002]
# ['left_foot', 0.0098794, 0.0626452, 0.0790429]
# ['right_hip', -0.0587641, 0.0021088, 0.8116835]
# ['right_knee', -0.2280848, -0.2376039, 0.5526004]
# ['right_ankle', -0.3267425, -0.0290857, 0.1672115]
# ['right_foot', -0.4289987, -0.1287983, 0.0921694]
# ['spine1', -0.000277, 0.025322900000000002, 1.0333398]
# ['spine2', -0.0179848, -0.0840019, 1.1425654]
# ['spine3', -0.0398005, -0.1412528, 1.1637662]
# ['neck', -0.0704473, -0.22376939999999998, 1.3134917]
# ['head', -0.0296905, -0.3813451, 1.3456922999999998]
# ['jaw', -0.0513658, -0.3807677, 1.3495071]
# ['left_eye', 0.0018703, -0.4526724, 1.3169371]
# ['right_eye', -0.0628705, -0.463581, 1.3144095]
# ['left_collar', -0.0071395, -0.1908796, 1.2307297000000001]
# ...
